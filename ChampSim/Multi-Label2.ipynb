# %%
from tqdm import tqdm 
import tensorflow as tf
from tensorflow import keras
from keras import Model
from keras.layers import Dense, Activation, Embedding, concatenate, Input, Flatten, LSTM, TextVectorization
from keras.optimizers import Adam
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import numpy as np 
from sklearn.metrics import multilabel_confusion_matrix, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %% [markdown]
# # Model 1

# %% [markdown]
# ### Loading data

# %%
X = np.load("./x.npy", allow_pickle=True)
y = np.load("./y.npy", allow_pickle=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print(X[:5])
# Out:
# [['409981' '98f5690f083e' 77]
#  ['409a14' '98f5690f283e' 0]
#  ['409a14' '98f5690f483e' 0]
#  ['409a14' '8ad3301be83e' 0]
#  ['4098b0' '8ad3301c283e' 1]]

# %% [markdown]
# ### Pre-process the input data

# %%
def address_split(x):
  vzfill = np.vectorize(np.char.zfill)
  x_PC = x[:, 0]
  x_PC = vzfill(x_PC, 8)
  x_PC = np.asarray(x_PC)
  x_addr = x[:, 1]
  x_addr = vzfill(x_addr, 12)
  x_addr_page = [x_addr[i][0:8] for i in range(0, x_addr.shape[0])]
  x_addr_page = np.asarray(x_addr_page)
  x_addr_offset = [x_addr[i][8:12] for i in range(0, x_addr.shape[0])]
  x_addr_offset = np.asarray(x_addr_offset)
  x_miss_distance = np.asarray(x[:, 2]).astype('float32')

  return x_PC, x_addr_page, x_addr_offset, x_miss_distance

# %%
X_train_PC, X_train_addr_page, X_train_addr_offset, x_train_miss_distance = address_split(X_train)
X_test_PC, X_test_addr_page, X_test_addr_offset, x_test_miss_distance = address_split(X_test)

# %%
unique, counts = np.unique(X_train_addr_page, return_counts=True)
unique_page_count = len(counts)
print("Unique page count is : " + str(unique_page_count))

unique, counts = np.unique(X_train_addr_offset, return_counts=True)
unique_offset_count = len(counts)
print("Unique offset count is : " + str(unique_offset_count))

unique, counts = np.unique(X_train_PC, return_counts=True)
unique_PC_count = len(counts)
print("Unique PC count is : " + str(unique_PC_count))
# Out:
# Unique page count is : 150
# Unique offset count is : 3016
# Unique PC count is : 21

# %%
x_train = [X_train_PC, X_train_addr_page, X_train_addr_offset, x_train_miss_distance]
x_test = [X_test_PC, X_test_addr_page, X_test_addr_offset, x_test_miss_distance]

# %%
type(x_test_miss_distance[0])
# Out:
# numpy.float32

# %%
page_input = Input(shape = (1,), dtype = tf.string)
page_vectorize_layer = TextVectorization(unique_page_count, output_mode = 'int', output_sequence_length = 1)
page_vectorize_layer.adapt(X_train_addr_page)
vectorized_page = page_vectorize_layer(page_input)
page_embedding = Embedding(unique_page_count, 20)(vectorized_page)
page_embedding = Flatten()(page_embedding)

offset_input = Input(shape = (1,), dtype = tf.string)
offset_vectorize_layer = TextVectorization(unique_offset_count, output_mode = 'int', output_sequence_length = 1)
offset_vectorize_layer.adapt(X_train_addr_offset)
vectorized_offset = offset_vectorize_layer(offset_input)
offset_embedding = Embedding(input_dim = unique_offset_count, output_dim = 20)(vectorized_offset)
offset_embedding = Flatten()(offset_embedding)

PC_input = Input(shape = (1,), dtype = tf.string)
PC_vectorize_layer = TextVectorization(unique_offset_count, output_mode = 'int', output_sequence_length = 1)
PC_vectorize_layer.adapt(X_train_PC)
vectorized_PC = PC_vectorize_layer(PC_input)
PC_embedding = Embedding(input_dim = unique_offset_count, output_dim = 20)(vectorized_PC)
PC_embedding = Flatten()(PC_embedding)

Miss_Distance_Input = Input(shape = (1,))

Concatenate_Input = concatenate([page_embedding, offset_embedding, PC_embedding, Miss_Distance_Input])
output = Dense(3, activation = "sigmoid")(Concatenate_Input)
model = Model(inputs=[page_input, offset_input, PC_input, Miss_Distance_Input], outputs=output)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_24 (InputLayer)          [(None, 1)]          0           []
#
#  input_25 (InputLayer)          [(None, 1)]          0           []
#
#  input_26 (InputLayer)          [(None, 1)]          0           []
#
#  text_vectorization_18 (TextVec  (None, 1)           0           ['input_24[0][0]']
#  torization)
#
#  text_vectorization_19 (TextVec  (None, 1)           0           ['input_25[0][0]']
#  torization)
#
#  text_vectorization_20 (TextVec  (None, 1)           0           ['input_26[0][0]']
#  torization)
#
#  embedding_18 (Embedding)       (None, 1, 20)        3000        ['text_vectorization_18[0][0]']
#
#  embedding_19 (Embedding)       (None, 1, 20)        60320       ['text_vectorization_19[0][0]']
#
#  embedding_20 (Embedding)       (None, 1, 20)        60320       ['text_vectorization_20[0][0]']
#
#  flatten_18 (Flatten)           (None, 20)           0           ['embedding_18[0][0]']
#
#  flatten_19 (Flatten)           (None, 20)           0           ['embedding_19[0][0]']
#
#  flatten_20 (Flatten)           (None, 20)           0           ['embedding_20[0][0]']
#
#  input_27 (InputLayer)          [(None, 1)]          0           []
#
#  concatenate_4 (Concatenate)    (None, 61)           0           ['flatten_18[0][0]',
#                                                                   'flatten_19[0][0]',
#                                                                   'flatten_20[0][0]',
#                                                                   'input_27[0][0]']
#
#  dense_3 (Dense)                (None, 3)            186         ['concatenate_4[0][0]']
#
# ==================================================================================================
# Total params: 123,826
# Trainable params: 123,826
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
learning_rate = 1e-3
epochs = 200
batch_size = 500

# %%
opt = Adam(learning_rate=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0, amsgrad=False)
model.compile(loss='binary_crossentropy', metrics=["categorical_accuracy"],
              optimizer=opt)
model.fit(x_train, y_train, epochs = epochs, batch_size=100)
# Out:
# Epoch 1/200
# 90/90 [==============================] - 1s 1ms/step - loss: 0.5582 - categorical_accuracy: 0.0825
# Epoch 2/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3804 - categorical_accuracy: 0.1006
# Epoch 3/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3409 - categorical_accuracy: 0.5926
# Epoch 4/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3294 - categorical_accuracy: 0.9429
# Epoch 5/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3248 - categorical_accuracy: 0.9429
# Epoch 6/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3213 - categorical_accuracy: 0.9429
# Epoch 7/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3180 - categorical_accuracy: 0.9429
# Epoch 8/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3155 - categorical_accuracy: 0.9429
# Epoch 9/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 10/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 11/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 12/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 13/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 14/200
# 90/90 [==============================] - 0s 2ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 15/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 16/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 17/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 18/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9428
# Epoch 19/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9427
# Epoch 20/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 21/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 22/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 23/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 24/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 25/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 26/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 27/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 28/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 29/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 30/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9428
# Epoch 31/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3141 - categorical_accuracy: 0.9429
# Epoch 32/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 33/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9412
# Epoch 34/200
# 90/90 [==============================] - 0s 2ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 35/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9395
# Epoch 36/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 37/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9352
# Epoch 38/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 39/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 40/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9403
# Epoch 41/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 42/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 43/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 44/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 45/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9417
# Epoch 46/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 47/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 48/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3141 - categorical_accuracy: 0.9429
# Epoch 49/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 50/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 51/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3145 - categorical_accuracy: 0.9429
# Epoch 52/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 53/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 54/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 55/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 56/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3147 - categorical_accuracy: 0.9429
# Epoch 57/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 58/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9413
# Epoch 59/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 60/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 61/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 62/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9428
# Epoch 63/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 64/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9406
# Epoch 65/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 66/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 67/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3145 - categorical_accuracy: 0.9429
# Epoch 68/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9420
# Epoch 69/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 70/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3145 - categorical_accuracy: 0.9416
# Epoch 71/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 72/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 73/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 74/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 75/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 76/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9427
# Epoch 77/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3145 - categorical_accuracy: 0.9399
# Epoch 78/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 79/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 80/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 81/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 82/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 83/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 84/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9420
# Epoch 85/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 86/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 87/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3145 - categorical_accuracy: 0.9429
# Epoch 88/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9420
# Epoch 89/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9428
# Epoch 90/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 91/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9426
# Epoch 92/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 93/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 94/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 95/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 96/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 97/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9427
# Epoch 98/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9425
# Epoch 99/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 100/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 101/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3147 - categorical_accuracy: 0.9429
# Epoch 102/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 103/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 104/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 105/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 106/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 107/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9424
# Epoch 108/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9384
# Epoch 109/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3145 - categorical_accuracy: 0.9416
# Epoch 110/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 111/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 112/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 113/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 114/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9399
# Epoch 115/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3145 - categorical_accuracy: 0.9429
# Epoch 116/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9386
# Epoch 117/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9412
# Epoch 118/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 119/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 120/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 121/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3146 - categorical_accuracy: 0.9429
# Epoch 122/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 123/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 124/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 125/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 126/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 127/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9410
# Epoch 128/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 129/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 130/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 131/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 132/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9414
# Epoch 133/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9412
# Epoch 134/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9418
# Epoch 135/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3146 - categorical_accuracy: 0.9429
# Epoch 136/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 137/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 138/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 139/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 140/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 141/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 142/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 143/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 144/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 145/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 146/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3141 - categorical_accuracy: 0.9429
# Epoch 147/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 148/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 149/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 150/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9423
# Epoch 151/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 152/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 153/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 154/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 155/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9377
# Epoch 156/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 157/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 158/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 159/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9397
# Epoch 160/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9396
# Epoch 161/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 162/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3145 - categorical_accuracy: 0.9429
# Epoch 163/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 164/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 165/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 166/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 167/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 168/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 169/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3145 - categorical_accuracy: 0.9429
# Epoch 170/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 171/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 172/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 173/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 174/200
# 90/90 [==============================] - 0s 2ms/step - loss: 0.3142 - categorical_accuracy: 0.9429
# Epoch 175/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9427
# Epoch 176/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3145 - categorical_accuracy: 0.9429
# Epoch 177/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3145 - categorical_accuracy: 0.9427
# Epoch 178/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 179/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 180/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 181/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9409
# Epoch 182/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9426
# Epoch 183/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9400
# Epoch 184/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 185/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 186/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 187/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 188/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 189/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 190/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 191/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3146 - categorical_accuracy: 0.9429
# Epoch 192/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 193/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 194/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3142 - categorical_accuracy: 0.9406
# Epoch 195/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429
# Epoch 196/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9427
# Epoch 197/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9429
# Epoch 198/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3145 - categorical_accuracy: 0.9428
# Epoch 199/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3143 - categorical_accuracy: 0.9422
# Epoch 200/200
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3144 - categorical_accuracy: 0.9429

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print('Accuracy: %f' % (accuracy*100))
y_new = model.predict_on_batch(x_train)
# Out:
# Accuracy: 94.729787

# %%
def confusion(test_data, model, ground_truth, labels):
  predicted = model.predict_on_batch(test_data)
  predicted = predicted >= 0.5
  labels = ['lfu', 'lru', 'FIFO']
  gridspec = {'width_ratios': [1, 1, 1, 0.1]}
  fig, axes = plt.subplots(1, 4, figsize=(16, 5), gridspec_kw=gridspec)
  axes = axes.ravel()

  for i in range(3):
    disp = ConfusionMatrixDisplay(confusion_matrix(ground_truth[:, i],
                                                    predicted[:, i]),
                                  display_labels=[0, 1])
    disp.plot(ax=axes[i], values_format='.4g')
    disp.ax_.set_title(labels[i])
    disp.im_.colorbar.remove()
    if i !=0:
      disp.ax_.set_ylabel('')
  plt.subplots_adjust(wspace=0.1, hspace=0.1)
  fig.colorbar(disp.im_, cax=axes[3])
  plt.show()



labels = ['lfu', 'lru', 'FIFO']
confusion(x_test, model, y_test, labels)

# %%
import pandas as pd

df = pd.read_csv("./llc_access_trace.csv", sep=',')
df.columns = ['PC','Address']

# %%
from collections import deque, defaultdict

def hitRate(traces_pd, cache_size, model):
    cache = set()
    lru_recency = deque()
    lfu_frequency = defaultdict()
    fifo_order = deque()
    hit = 0
    miss = 0
    MissDistance = 0

    for i, row in tqdm(traces_pd.iterrows(), total=traces_pd.shape[0], leave = False):
        trace = row['Address']
         # Pop the visit position
        if trace in cache:
            hit += 1
            # update the lfu frequency
            lfu_frequency[trace] += 1
            # update the lfu 
            lru_recency.remove(trace)
            lru_recency.append(trace)
            MissDistance += 1

        elif len(cache) < cache_size:
            miss += 1
            cache.add(trace)
            # update the lfu
            lfu_frequency[trace] = 1
            # update the lru
            lru_recency.append(trace)
            # update the fifo
            fifo_order.append(trace)
        else:
            miss += 1
            # lfu propse a candidate
            lfu_candidate, f = min(lfu_frequency.items(), key=lambda a: a[1])
            # lru propose a candidate
            lru_candidate = lru_recency[0]
            # fifo propose a candidate
            fifo_candidate = fifo_order[0]
            candidates = [lfu_candidate, lru_candidate, fifo_candidate]
            # determine which one has the longest trace distance
            x_PC = row['PC']
            x_PC = x_PC.zfill(8)
            x_addr = row['Address']
            x_addr = x_addr.zfill(12)
            x_addr_page = x_addr[0:8]
            x_addr_offset = x_addr[8:12]
            x_addr_page = np.asarray([x_addr_page])
            x_addr_offset = np.asarray([x_addr_offset])
            x_PC = np.asarray([x_PC])
            MissDistance = np.asanyarray([MissDistance]).astype('float32')
            predicted = model.predict_on_batch([x_PC, x_addr_page, x_addr_offset, MissDistance])
            evicted_candidate = candidates[np.argmax(predicted)]
            MissDistance = 0
            # update the cache
            cache.remove(evicted_candidate)
            cache.add(trace)

            # update the meta data
            # update the lru meta data
            lru_recency.remove(evicted_candidate)
            lru_recency.append(trace)
            # update the lfu meta data
            lfu_frequency.pop(evicted_candidate)
            lfu_frequency[trace] = 1
            # 
            fifo_order.remove(evicted_candidate)
            fifo_order.append(trace)
    return hit/(hit+miss)



df = pd.read_csv("./llc_access_trace.csv", sep=',')
df.columns = ['PC','Address']
df.head()


hitrate = hitRate(df,  2048, model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\yuwen\Documents\Projects\cache_replacement\ChampSim\Model2.ipynb Cell 18' in <cell line: 70>()
#      <a href='vscode-notebook-cell:/c%3A/Users/yuwen/Documents/Projects/cache_replacement/ChampSim/Model2.ipynb#ch0000015?line=63'>64</a>             fifo_order.append(trace)
#      <a href='vscode-notebook-cell:/c%3A/Users/yuwen/Documents/Projects/cache_replacement/ChampSim/Model2.ipynb#ch0000015?line=64'>65</a>     return hit/(hit+miss)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/yuwen/Documents/Projects/cache_replacement/ChampSim/Model2.ipynb#ch0000015?line=69'>70</a> hitrate = hitRate(df,  2048, model)
#
# NameError: name 'df' is not defined
